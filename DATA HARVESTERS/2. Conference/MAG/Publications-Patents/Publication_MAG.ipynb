# %%
# @title ##### Get Conference Data

"""
MAG - Microsoft Academic Graph
==============================
MAG provides data of all research papers.
""" 
import json
import requests
from pprint import pprint
import csv
import pandas as pd
from datetime import date
import ast

class MAG:
  """
  Arguments:
  ---------
    - Field : Name of the field we need to fetch data for
    - start_date : start date of data
    - end_date : end date of data
    - retry : Number of attemts to connect to MAG
  """ 
  def __init__(self, **kwargs):
    self.start_date = kwargs.get('start_date')
    self.end_date = kwargs.get('end_date')
    self.field = kwargs.get('field')
    self.retry = kwargs.get('retry')

  def getData(self):
    """
    Data from MAG.

    RETURNS
    -------
    - Return dataframe containing MAG data
    """
    from time import sleep
    retry = 0
    while(True):
        try:
          if(retry == self.retry):
            print("Failed to connect to MAG \
                      please recheck the connection")
            break
          endpoint = 'https://api.labs.cognitive.microsoft.com/'
          api_version = 'academic/v1.0/evaluate?'
          headers = {'Ocp-Apim-Subscription-Key': 'f4191fe719cf4659813a86e6830b2546',}
          dates = []
          dates.append(pd.date_range(start=self.start_date,end=self.end_date).strftime("%Y-%m-%d").tolist())
          dates = dates[0]
          count = 0
          for i in range(len(dates)-1):
            try:
              print(dates[i])
              searchstring = "And(Composite(F.FN='{}'),D=['{}','{}'])".format(self.field,dates[i],dates[i+1])
              url = endpoint + api_version + "expr=" + searchstring + "&attributes=Ti,Y,D,AA.DAfN,CC,Pt" + "&count=100000" + "&orderby=Y:asc"
              print(url)
              response  = requests.get(url, headers=headers)
              query = response.json()
              self.query = query
              self.json_to_csv()
              if count == 0:
                da = pd.read_csv('data_file.csv')
                count+=1
              else:
                df = pd.read_csv('data_file.csv')
                da = pd.read_csv('MAG.csv')
                df = df.drop('Unnamed :0',axis = 1)
                da = da.drop('Unnamed :0',axis = 1)
                da = pd.concat([da,df])
              da.to_csv('MAG.csv')
            except:
              pass
          self.data = self.basicPreprocess()
          self.data = self.grid()
            
          # pprint (self.query)
          return self.data
        except Exception as e:
                retry = retry + 1
                print("MAG Exception: ", e)
                print("Reattempting the server: ", retry)
                sleep(60)  

  def json_to_csv(self):
    json_object = json.dumps(self.query, indent = 6) 
    with open("mag.json", "w") as outfile: 
      outfile.write(json_object)
          
    with open('mag.json') as json_file: 
      data = json.load(json_file) 

    data_entities = data['entities'] 

    # now we will open a file for writing 
    data_file = open('data_file.csv', 'w') 

    # create the csv writer object 
    csv_writer = csv.writer(data_file) 

    # Counter variable used for writing 
    # headers to the CSV file 
    count = 0

    for ent in data_entities: 
      if count == 0: 

        # Writing headers of CSV file 
        header = ent.keys() 
        csv_writer.writerow(header) 
        count += 1

      # Writing data of CSV file 
      csv_writer.writerow(ent.values()) 

    data_file.close()

  def basicPreprocess(self):
    """
    Performs basic preprocessing steps.
    """
    da = pd.read_csv('data_file.csv')
    da['AA'] = da['AA'].apply(ast.literal_eval)
    df1 = pd.concat({k:pd.DataFrame(v) for k, v in da['AA'].items()})
    da = da.join(df1.reset_index(level=1, drop=True)).reset_index(drop=True)
    da = da.drop(['logprob','prob','AA','D'],axis = 1)
    da = da.rename(columns={'DAfN':'Affiliation','Y':'Year','Ti':'Title','CC':'Citation_Count','Pt':'Publication_type'})
    da.Publication_type.replace([0, 1, 2, 3, 4, 5, 6, 7, 8], ['Unknown','Journal article','Patent','Conference paper','Book chapter','Book','Book reference entry','Dataset','Repository'], inplace=True)
    da.to_csv("data_file.csv")

    return da 

  def grid(self):
    da = pd.read_csv("data_file.csv")
    grid = pd.read_csv('/content/drive/My Drive/AI Index Visualization Project/DATASETS/Conference data/Country data/Grid/grid.csv')
    grid = grid[['Name','Country']].rename(columns={'Name':'Affiliation'})
    da_country = pd.merge(da,grid,how = 'left', on = ['Affiliation'])
    da_country = da_country.fillna('')
    da_country = da_country.drop(['Unnamed: 0'],axis =1)
    da_country.to_csv('data_file.csv')
    return da_country

  

def main():
  Field = "Artificial Intelligence" #@param {type : "string"}
  Field = Field.lower()
  Start_date = "1920-01-01" #@param {type : "string"}
  End_date = "2020-07-01" #@param {type : "string"}
  a = MAG(field = Field,start_date = Start_date,end_date = End_date,retry=5)
  q = a.getData()
  q.to_csv(f"/content/drive/My Drive/AI Index Visualization Project/DATASETS/Publication data/Version 1/{Field}.csv")

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-01-22','1937-01-23'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-01-23
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-01-23','1937-01-24'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-01-24
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-01-24','1937-01-25'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-01-25
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-01-25','1937-01-26'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-01-26
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-01-26','1937-01-27'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-01-27
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-01-27','1937-01-28'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-01-28
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-01-28','1937-01-29'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-01-29
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-01-29','1937-01-30'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-01-30
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-01-30','1937-01-31'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-01-31
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-01-31','1937-02-01'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-01
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-01','1937-02-02'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-02
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-02','1937-02-03'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-03
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-03','1937-02-04'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-04
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-04','1937-02-05'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-05
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-05','1937-02-06'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-06
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-06','1937-02-07'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-07
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-07','1937-02-08'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-08
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-08','1937-02-09'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-09
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-09','1937-02-10'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-10
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-10','1937-02-11'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-11
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-11','1937-02-12'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-12
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-12','1937-02-13'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-13
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-13','1937-02-14'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-14
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-14','1937-02-15'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-15
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-15','1937-02-16'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-16
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-16','1937-02-17'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-17
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-17','1937-02-18'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-18
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-18','1937-02-19'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-19
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-19','1937-02-20'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-20
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-20','1937-02-21'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-21
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-21','1937-02-22'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-22
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-22','1937-02-23'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-23
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-23','1937-02-24'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-24
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-24','1937-02-25'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-25
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-25','1937-02-26'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-26
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-26','1937-02-27'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-27
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-27','1937-02-28'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-02-28
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-02-28','1937-03-01'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-01
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-01','1937-03-02'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-02
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-02','1937-03-03'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-03
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-03','1937-03-04'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-04
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-04','1937-03-05'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-05
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-05','1937-03-06'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-06
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-06','1937-03-07'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-07
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-07','1937-03-08'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-08
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-08','1937-03-09'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-09
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-09','1937-03-10'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-10
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-10','1937-03-11'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-11
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-11','1937-03-12'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-12
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-12','1937-03-13'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-13
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-13','1937-03-14'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-14
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-14','1937-03-15'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-15
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-15','1937-03-16'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-16
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-16','1937-03-17'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-17
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-17','1937-03-18'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-18
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-18','1937-03-19'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-19
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-19','1937-03-20'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-20
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-20','1937-03-21'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-21
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-21','1937-03-22'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-22
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-22','1937-03-23'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-23
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-23','1937-03-24'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-24
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-24','1937-03-25'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-25
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-25','1937-03-26'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-26
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-26','1937-03-27'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-27
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-27','1937-03-28'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-28
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-28','1937-03-29'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-29
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-29','1937-03-30'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-30
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-30','1937-03-31'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-03-31
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-03-31','1937-04-01'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-04-01
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-04-01','1937-04-02'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-04-02
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-04-02','1937-04-03'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-04-03
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-04-03','1937-04-04'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-04-04
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-04-04','1937-04-05'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-04-05
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-04-05','1937-04-06'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-04-06
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-04-06','1937-04-07'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-04-07
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-04-07','1937-04-08'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-04-08
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-04-08','1937-04-09'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-04-09
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-04-09','1937-04-10'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1937-04-10
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1937-04
22'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-09-22
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-09-22','1943-09-23'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-09-23
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-09-23','1943-09-24'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-09-24
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-09-24','1943-09-25'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-09-25
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-09-25','1943-09-26'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-09-26
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-09-26','1943-09-27'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-09-27
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-09-27','1943-09-28'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-09-28
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-09-28','1943-09-29'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-09-29
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-09-29','1943-09-30'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-09-30
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-09-30','1943-10-01'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-01
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-01','1943-10-02'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-02
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-02','1943-10-03'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-03
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-03','1943-10-04'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-04
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-04','1943-10-05'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-05
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-05','1943-10-06'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-06
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-06','1943-10-07'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-07
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-07','1943-10-08'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-08
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-08','1943-10-09'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-09
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-09','1943-10-10'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-10
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-10','1943-10-11'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-11
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-11','1943-10-12'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-12
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-12','1943-10-13'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-13
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-13','1943-10-14'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-14
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-14','1943-10-15'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-15
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-15','1943-10-16'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-16
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-16','1943-10-17'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-17
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-17','1943-10-18'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-18
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-18','1943-10-19'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-19
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-19','1943-10-20'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-20
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-20','1943-10-21'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-21
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-21','1943-10-22'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-22
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-22','1943-10-23'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-23
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-23','1943-10-24'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-24
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-24','1943-10-25'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-25
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-25','1943-10-26'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-26
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-26','1943-10-27'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-27
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-27','1943-10-28'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-28
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-28','1943-10-29'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-29
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-29','1943-10-30'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-30
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-30','1943-10-31'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-10-31
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-10-31','1943-11-01'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-01
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-01','1943-11-02'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-02
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-02','1943-11-03'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-03
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-03','1943-11-04'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-04
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-04','1943-11-05'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-05
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-05','1943-11-06'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-06
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-06','1943-11-07'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-07
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-07','1943-11-08'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-08
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-08','1943-11-09'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-09
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-09','1943-11-10'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-10
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-10','1943-11-11'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-11
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-11','1943-11-12'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-12
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-12','1943-11-13'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-13
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-13','1943-11-14'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-14
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-14','1943-11-15'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-15
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-15','1943-11-16'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-16
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-16','1943-11-17'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-17
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-17','1943-11-18'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-18
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-18','1943-11-19'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-19
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-19','1943-11-20'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-20
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-20','1943-11-21'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-21
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-21','1943-11-22'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-22
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-22','1943-11-23'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-23
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-23','1943-11-24'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-24
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-24','1943-11-25'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-25
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-25','1943-11-26'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc
# 1943-11-26
# https://api.labs.cognitive.microsoft.com/academic/v1.0/evaluate?expr=And(Composite(F.FN='artificial intelligence'),D=['1943-11-26','1943-11-27'])&attributes=Ti,Y,D,AA.DAfN,CC,Pt&count=100000&orderby=Y:asc

# %%
da = pd.read_csv('data_file.csv')
da.tail(30)
# Out:
#        Unnamed: 0  ... Country
# 20415       20415  ...     NaN
# 20416       20416  ...   Japan
# 20417       20417  ...   Japan
# 20418       20418  ...     NaN
# 20419       20419  ...     NaN
# 20420       20420  ...     NaN
# 20421       20421  ...     NaN
# 20422       20422  ...     NaN
# 20423       20423  ...     NaN
# 20424       20424  ...     NaN
# 20425       20425  ...     NaN
# 20426       20426  ...     NaN
# 20427       20427  ...     NaN
# 20428       20428  ...     NaN
# 20429       20429  ...   China
# 20430       20430  ...     NaN
# 20431       20431  ...     NaN
# 20432       20432  ...     NaN
# 20433       20433  ...     NaN
# 20434       20434  ...     NaN
# 20435       20435  ...     NaN
# 20436       20436  ...     NaN
# 20437       20437  ...     NaN
# 20438       20438  ...     NaN
# 20439       20439  ...     NaN
# 20440       20440  ...     NaN
# 20441       20441  ...     NaN
# 20442       20442  ...     NaN
# 20443       20443  ...     NaN
# 20444       20444  ...     NaN
#
# [30 rows x 7 columns]
