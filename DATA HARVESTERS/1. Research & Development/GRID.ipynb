# %% [markdown]
# #### Loading the affliation data

# %%
import pandas as pd
df = pd.read_csv("/content/drive/My Drive/AI Index Visualization Project/DATASETS/Conference data/Fields wise Affiliations/All_conference.csv")
df = df.drop('Unnamed: 0',axis = 1)

# %%
df
# Out:
#          Date         Field_of_study  ... Publication_Count  Conference
# 0        1980               a domain  ...                 4        AAAI
# 1        1980            abstraction  ...                 1        AAAI
# 2        1980            abstraction  ...                 2        AAAI
# 3        1980  affine transformation  ...                 2        AAAI
# 4        1980                algebra  ...                 1        AAAI
# ...       ...                    ...  ...               ...         ...
# 2361016  2019                  worry  ...                 1         UAI
# 2361017  2019                  worry  ...                 2         UAI
# 2361018  2019                  worry  ...                 1         UAI
# 2361019  2019                  worry  ...                 1         UAI
# 2361020  2019                  worry  ...                 2         UAI
#
# [2361021 rows x 5 columns]

# %% [markdown]
# #### Country mapping
#
#
# *   address: To get latitude and longitude.
# *   grid: To get city, state and country data
#
# Mapping country
# *   First we merge address and grid to get latitude and ongitude data.
# * Then we merge Affiliation data with the grid data based on affiliation name.
# * Finally we remove all entries with country = NULL

# %%
#@title Country mapping

address = pd.read_csv('/content/drive/My Drive/AI Index Visualization Project/DATASETS/Conference data/Country data/Grid/addresses.csv')
grid = pd.read_csv('/content/drive/My Drive/AI Index Visualization Project/DATASETS/Conference data/Country data/Grid/grid.csv')
address = address.rename(columns={'grid_id':'ID'})
c = pd.merge(address,grid,how = 'inner', on = ['ID'])
c = c[['Name','City','State','Country','lat','lng']]
c = c.rename(columns={'Name':'Affiliation'})
cc = pd.merge(df,c,how = 'left', on = ['Affiliation'])
cc = cc.fillna('')
cc = cc[cc['lat']!='']
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,2,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
cc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2bd2965b6208> in <module>()
# ----> 1 cc
#
# NameError: name 'cc' is not defined
