# %%
# @title ##### Get Conference Data for a specific author

"""
MAG - Microsoft Academic Graph
==============================
MAG provides data of all research papers.
""" 
import json
import requests
from pprint import pprint
import csv
import pandas as pd
from datetime import date
import ast

class MAG:
  """
  Arguments:
  ---------
    - country string : Country of which we need data
    - doctype : [Book, BookChapter, Conference, Dataset, Journal, Patent, Repository] Type of document.
    - start_date : start date of data
    - end_date : end date of data
    - field_of_study : The field we need data for like (artificial intelligence, robotics) 
    - retry : Number of attemts to connect to MAG
  """ 
  def __init__(self, **kwargs):
    df = pd.read_excel("/content/drive/My Drive/AI Index Visualization Project/DATA HARVESTORS/MAG/Lifecycle/Author.xlsx")
    self.e_d = date.today().strftime("%Y-%m-%d")
    self.s_d = kwargs.get('start_date').split('-')
    self.e_d = kwargs.get('end_date').split('-')
    self.s_d = int(self.s_d[0])
    self.e_d = int(self.e_d[0])
    self.start_date = kwargs.get('start_date')
    self.end_date = kwargs.get('end_date')
    self.author = kwargs.get('author')
    self.retry = kwargs.get('retry')
    self.author_id = int(df[df['Author']==self.author]['Author ID'])

  def basicPreprocess(self):
    """
    Performs basic preprocessing steps.
    """
    da = pd.read_csv('data_file.csv')
    da['AA'] = da['AA'].apply(ast.literal_eval)
    df1 = pd.concat({k:pd.DataFrame(v) for k, v in da['AA'].items()})
    da = da.join(df1.reset_index(level=1, drop=True)).reset_index(drop=True)
    da = da.drop(['logprob','prob','AA'],axis = 1)
    da = da.rename(columns={'AuId':'Author_id','Ti':'Title','AuN':'Author','DAfN':'Affiliation','Y':'Date'})
    da = da[da['Author_id']==self.author_id]
    da.to_csv("data_file.csv")
    return da

  def json_to_csv(self):
    json_object = json.dumps(self.query, indent = 6) 
    with open("mag.json", "w") as outfile: 
      outfile.write(json_object)     
    with open('mag.json') as json_file: 
      data = json.load(json_file) 

    data_entities = data['entities'] 

    # now we will open a file for writing 
    data_file = open('data_file.csv', 'w') 

    # create the csv writer obGCP Bigtableject 
    csv_writer = csv.writer(data_file) 

    # Counter variable used for writing 
    # headers to the CSV file 
    count = 0

    for ent in data_entities: 
      if count == 0: 

        # Writing headers of CSV file 
        header = ent.keys() 
        csv_writer.writerow(header) 
        count += 1

      # Writing data of CSV file 
      csv_writer.writerow(ent.values()) 

    data_file.close() 

  def grid(self):
    da = pd.read_csv("data_file.csv")
    grid = pd.read_csv('/content/drive/My Drive/AI Index Visualization Project/DATASETS/Conference data/Country data/Grid/grid.csv')
    grid = grid[['Name','Country']].rename(columns={'Name':'Affiliation'})
    da_country = pd.merge(da,grid,how = 'left', on = ['Affiliation'])
    da_country = da_country.fillna('')
    da_country.to_csv('data_file.csv')
    return da_country

  def getData(self):
    """
    Data from MAG.

    RETURNS
    -------
    - Return dataframe containing MAG data
    """
    from time import sleep
    retry = 0
    while(True):
        try:
          if(retry == self.retry):
            print("Failed to connect to MAG \
                      please recheck the connection")
            break
          endpoint = 'https://api.labs.cognitive.microsoft.com/'
          api_version = 'academic/v1.0/evaluate?'
          headers = {'Ocp-Apim-Subscription-Key': 'd9b12d4dac1f4ccea5e60d6f562b5cc1',}
          searchstring = "And(Composite(AA.AuId={}),Y=[{},{}])".format(self.author_id,self.s_d,self.e_d)
          url = endpoint + api_version + "expr=" + searchstring + "&attributes=Ti,AA.AuN,AA.DAfN,AA.AuId,Y" + "&count=100000" + "&orderby=Y:asc"
          response  = requests.get(url, headers=headers)
          query = response.json()
          self.query = query
          self.json_to_csv()
          self.data = self.basicPreprocess()
          self.data = self.grid()
          pprint(self.query)
          return self.data
        except Exception as e:
                retry = retry + 1
                print("MAG Exception: ", e)
                print("Reattempting the server: ", retry)
                sleep(60)

def main():
  Author = "andrew y ng" #@param {type : "string"}
  Start_date = "1980-01-01" #@param {type : "string"}
  End_date = "2021-01-01" #@param {type : "string"}  
  a = MAG(author = Author,start_date = Start_date,end_date = End_date,retry=5)
  q = a.getData()
  q.to_csv(f"/content/drive/My Drive/AI Index Visualization Project/DATASETS/Conference data/Author/Lifecycle/{Author}.csv")

if __name__ == "__main__":
    main()
# Out:
# {'entities': [{'AA': [{'AuId': 2118586410,
#                        'AuN': 'michael kearns',
#                        'DAfN': 'Bell Labs'},
#                       {'AuId': 2078633956,
#                        'AuN': 'yishay mansour',
#                        'DAfN': 'Tel Aviv University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Carnegie Mellon University'},
#                       {'AuId': 2146939727,
#                        'AuN': 'dana ron',
#                        'DAfN': 'Hebrew University of Jerusalem'}],
#                'Ti': 'an experimental and theoretical comparison of model '
#                      'selection methods',
#                'Y': 1995,
#                'logprob': -18.878,
#                'prob': 6.3297823e-09},
#               {'AA': [{'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''}],
#                'Ti': 'preventing overfitting of cross validation data',
#                'Y': 1997,
#                'logprob': -19.718,
#                'prob': 2.7326336e-09},
#               {'AA': [{'AuId': 2118586410,
#                        'AuN': 'michael kearns',
#                        'DAfN': 'AT&T Labs'},
#                       {'AuId': 2078633956,
#                        'AuN': 'yishay mansour',
#                        'DAfN': 'Tel Aviv University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Carnegie Mellon University'}],
#                'Ti': 'an information theoretic analysis of hard and soft '
#                      'assignment methods for clustering',
#                'Y': 1997,
#                'logprob': -19.249,
#                'prob': 4.3678279e-09},
#               {'AA': [{'AuId': 2160582649, 'AuN': 'scott davies', 'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''},
#                       {'AuId': 2170629902,
#                        'AuN': 'andrew w moore',
#                        'DAfN': ''}],
#                'Ti': 'applying online search techniques to continuous state '
#                      'reinforcement learning',
#                'Y': 1998,
#                'logprob': -21.629,
#                'prob': 4.04245e-10},
#               {'AA': [{'AuId': 2117063646, 'AuN': 'roni rosenfeld', 'DAfN': ''},
#                       {'AuId': 2151014374, 'AuN': 'tom m mitchell', 'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''}],
#                'Ti': 'improving text classification by shrinkage',
#                'Y': 1998,
#                'logprob': -20.232,
#                'prob': 1.6343838e-09},
#               {'AA': [{'AuId': 2118586410,
#                        'AuN': 'michael kearns',
#                        'DAfN': 'AT&T Labs'},
#                       {'AuId': 2078633956,
#                        'AuN': 'yishay mansour',
#                        'DAfN': 'Tel Aviv University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Carnegie Mellon University'}],
#                'Ti': 'an information theoretic analysis of hard and soft '
#                      'assignment methods for clustering',
#                'Y': 1998,
#                'logprob': -19.249,
#                'prob': 4.3678279e-09},
#               {'AA': [{'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''}],
#                'Ti': 'on feature selection learning with exponentially many '
#                      'irrelevant features as training examples',
#                'Y': 1998,
#                'logprob': -18.347,
#                'prob': 1.07646308e-08},
#               {'AA': [{'AuId': 2131293038,
#                        'AuN': 'andrew mccallum',
#                        'DAfN': ''},
#                       {'AuId': 2396008703,
#                        'AuN': 'ronald rosenfeld',
#                        'DAfN': ''},
#                       {'AuId': 2151014374, 'AuN': 'tom m mitchell', 'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''}],
#                'Ti': 'improving text classification by shrinkage in a '
#                      'hierarchy of classes',
#                'Y': 1998,
#                'logprob': -17.684,
#                'prob': 2.0889901e-08},
#               {'AA': [{'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2435751034,
#                        'AuN': 'michael i jordan',
#                        'DAfN': 'University of California, Berkeley'}],
#                'Ti': 'approximate inference a lgorithms for two layer bayesian '
#                      'networks',
#                'Y': 1999,
#                'logprob': -20.929,
#                'prob': 8.140495e-10},
#               {'AA': [{'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2171585635,
#                        'AuN': 'ronald parr',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2167404190,
#                        'AuN': 'daphne koller',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'policy search via density estimation',
#                'Y': 1999,
#                'logprob': -20.265,
#                'prob': 1.5813293e-09},
#               {'AA': [{'AuId': 2118586410,
#                        'AuN': 'michael kearns',
#                        'DAfN': 'AT&T Labs'},
#                       {'AuId': 2078633956,
#                        'AuN': 'yishay mansour',
#                        'DAfN': 'Tel Aviv University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'University of California, Berkeley'}],
#                'Ti': 'approximate planning in large pomdps via reusable '
#                      'trajectories',
#                'Y': 1999,
#                'logprob': -18.611,
#                'prob': 8.2669516e-09},
#               {'AA': [{'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''},
#                       {'AuId': 2627203822, 'AuN': 'daishi harada', 'DAfN': ''},
#                       {'AuId': 2128362942,
#                        'AuN': 'stuart russell',
#                        'DAfN': ''}],
#                'Ti': 'policy invariance under reward transformations theory '
#                      'and application to reward shaping',
#                'Y': 1999,
#                'logprob': -17.745,
#                'prob': 1.96537043e-08},
#               {'AA': [{'AuId': 2118586410,
#                        'AuN': 'michael kearns',
#                        'DAfN': 'AT&T Labs'},
#                       {'AuId': 2078633956,
#                        'AuN': 'yishay mansour',
#                        'DAfN': 'Tel Aviv University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'University of California, Berkeley'}],
#                'Ti': 'a sparse sampling algorithm for near optimal planning in '
#                      'large markov decision processes',
#                'Y': 1999,
#                'logprob': -18.406,
#                'prob': 1.01478904e-08},
#               {'AA': [{'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2435751034,
#                        'AuN': 'michael i jordan',
#                        'DAfN': 'University of California, Berkeley'}],
#                'Ti': 'pegasus a policy search method for large mdps and pomdps',
#                'Y': 2000,
#                'logprob': -18.098,
#                'prob': 1.38082444e-08},
#               {'AA': [{'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'University of León'},
#                       {'AuId': 2128362942,
#                        'AuN': 'stuart russell',
#                        'DAfN': ''}],
#                'Ti': 'algorithms for inverse reinforcement learning',
#                'Y': 2000,
#                'logprob': -17.27,
#                'prob': 3.16034356e-08},
#               {'AA': [{'AuId': 1515167117,
#                        'AuN': 'j andrew bagnell',
#                        'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''},
#                       {'AuId': 2165347984,
#                        'AuN': 'jeff schneider',
#                        'DAfN': ''}],
#                'Ti': 'solving uncertain markov decision processes',
#                'Y': 2001,
#                'logprob': -20.694,
#                'prob': 1.0296983e-09},
#               {'AA': [{'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''},
#                       {'AuId': 2435751034,
#                        'AuN': 'michael i jordan',
#                        'DAfN': ''}],
#                'Ti': 'convergence rates of the voting gibbs classifier with '
#                      'application to bayesian feature selection',
#                'Y': 2001,
#                'logprob': -19.898,
#                'prob': 2.2824875e-09},
#               {'AA': [{'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2005707679,
#                        'AuN': 'alice x zheng',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2435751034,
#                        'AuN': 'michael i jordan',
#                        'DAfN': 'University of California, Berkeley'}],
#                'Ti': 'link analysis eigenvectors and stability',
#                'Y': 2001,
#                'logprob': -18.159,
#                'prob': 1.29911173e-08},
#               {'AA': [{'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2005707679,
#                        'AuN': 'alice x zheng',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2435751034,
#                        'AuN': 'michael i jordan',
#                        'DAfN': 'University of California, Berkeley'}],
#                'Ti': 'stable algorithms for link analysis',
#                'Y': 2001,
#                'logprob': -18.492,
#                'prob': 9.3116456e-09},
#               {'AA': [{'AuId': 2237822638, 'AuN': 'eric d brill', 'DAfN': ''},
#                       {'AuId': 2163619555, 'AuN': 'jimmy lin', 'DAfN': ''},
#                       {'AuId': 2137637256, 'AuN': 'michele banko', 'DAfN': ''},
#                       {'AuId': 676500258, 'AuN': 'susan t dumais', 'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''}],
#                'Ti': 'data intensive question answering',
#                'Y': 2001,
#                'logprob': -17.918,
#                'prob': 1.653147e-08},
#               {'AA': [{'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2435751034,
#                        'AuN': 'michael i jordan',
#                        'DAfN': 'University of California, Berkeley'}],
#                'Ti': 'on discriminative vs generative classifiers a comparison '
#                      'of logistic regression and naive bayes',
#                'Y': 2001,
#                'logprob': -17.198,
#                'prob': 3.3962801e-08},
#               {'AA': [{'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2435751034,
#                        'AuN': 'michael i jordan',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2097273326,
#                        'AuN': 'yair weiss',
#                        'DAfN': 'Hebrew University of Jerusalem'}],
#                'Ti': 'on spectral clustering analysis and an algorithm',
#                'Y': 2001,
#                'logprob': -15.468,
#                'prob': 1.915724061e-07},
#               {'AA': [{'AuId': 2289542319,
#                        'AuN': 'david m blei',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2435751034,
#                        'AuN': 'michael i jordan',
#                        'DAfN': 'University of California, Berkeley'}],
#                'Ti': 'latent dirichlet allocation',
#                'Y': 2001,
#                'logprob': -14.093,
#                'prob': 7.576835642e-07},
#               {'AA': [{'AuId': 2118586410,
#                        'AuN': 'michael kearns',
#                        'DAfN': 'University of Pennsylvania'},
#                       {'AuId': 2078633956,
#                        'AuN': 'yishay mansour',
#                        'DAfN': 'Tel Aviv University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'University of California, Berkeley'}],
#                'Ti': 'a sparse sampling algorithm for near optimal planning in '
#                      'large markov decision processes',
#                'Y': 2002,
#                'logprob': -18.406,
#                'prob': 1.01478904e-08},
#               {'AA': [{'AuId': 351197510,
#                        'AuN': 'eric p xing',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2435751034,
#                        'AuN': 'michael i jordan',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2128362942,
#                        'AuN': 'stuart russell',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'University of California, Berkeley'}],
#                'Ti': 'distance metric learning with application to clustering '
#                      'with side information',
#                'Y': 2002,
#                'logprob': -16.303,
#                'prob': 8.31183784e-08},
#               {'AA': [{'AuId': 2009612802,
#                        'AuN': 'james andrew bagnell',
#                        'DAfN': 'Carnegie Mellon University'},
#                       {'AuId': 85537834,
#                        'AuN': 'sham m kakade',
#                        'DAfN': 'University of Pennsylvania'},
#                       {'AuId': 2165347984,
#                        'AuN': 'jeff schneider',
#                        'DAfN': 'Carnegie Mellon University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'policy search by dynamic programming',
#                'Y': 2003,
#                'logprob': -19.065,
#                'prob': 5.2501982e-09},
#               {'AA': [{'AuId': 2129066351,
#                        'AuN': 'rajat raina',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2099244378,
#                        'AuN': 'yirong shen',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2131293038,
#                        'AuN': 'andrew mccallum',
#                        'DAfN': 'University of Massachusetts Amherst'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'classification with hybrid generative discriminative '
#                      'models',
#                'Y': 2003,
#                'logprob': -18.966,
#                'prob': 5.7965669e-09},
#               {'AA': [{'AuId': 2289542319, 'AuN': 'david m blei', 'DAfN': ''},
#                       {'AuId': 2435751034,
#                        'AuN': 'michael i jordan',
#                        'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''}],
#                'Ti': 'hierarchical bayesian models for applications in '
#                      'information retrieval',
#                'Y': 2003,
#                'logprob': -18.75,
#                'prob': 7.194133e-09},
#               {'AA': [{'AuId': 2955496651,
#                        'AuN': 'harrim kim',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2435751034,
#                        'AuN': 'michael i jordan',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2149692785,
#                        'AuN': 'shankar sastry',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'autonomous helicopter flight via reinforcement learning',
#                'Y': 2003,
#                'logprob': -18.559,
#                'prob': 8.7082063e-09},
#               {'AA': [{'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''},
#                       {'AuId': 2435751034,
#                        'AuN': 'michael i jordan',
#                        'DAfN': ''}],
#                'Ti': 'shaping and policy search in reinforcement learning',
#                'Y': 2003,
#                'logprob': -19.57,
#                'prob': 3.1685239e-09},
#               {'AA': [{'AuId': 2289542319,
#                        'AuN': 'david m blei',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2435751034,
#                        'AuN': 'michael i jordan',
#                        'DAfN': 'University of California, Berkeley'}],
#                'Ti': 'latent dirichlet allocation',
#                'Y': 2003,
#                'logprob': -14.093,
#                'prob': 7.576835642e-07},
#               {'AA': [{'AuId': 2955496651,
#                        'AuN': 'harrim kim',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'stable adaptive control with online learning',
#                'Y': 2004,
#                'logprob': -20.521,
#                'prob': 1.2241734e-09},
#               {'AA': [{'AuId': 2075956027,
#                        'AuN': 'sebastian thrun',
#                        'DAfN': 'Carnegie Mellon University'},
#                       {'AuId': 2167404190,
#                        'AuN': 'daphne koller',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 617670330,
#                        'AuN': 'zoubin ghahramani',
#                        'DAfN': 'University College London'},
#                       {'AuId': 2167801844,
#                        'AuN': 'hugh durrantwhyte',
#                        'DAfN': 'University of Sydney'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'simultaneous mapping and localization with sparse '
#                      'extended information filters theory and initial results',
#                'Y': 2004,
#                'logprob': -19.543,
#                'prob': 3.2552395e-09},
#               {'AA': [{'AuId': 92438100,
#                        'AuN': 'shai shalevshwartz',
#                        'DAfN': 'Hebrew University of Jerusalem'},
#                       {'AuId': 2292250447,
#                        'AuN': 'yoram singer',
#                        'DAfN': 'Hebrew University of Jerusalem'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'online and batch learning of pseudo metrics',
#                'Y': 2004,
#                'logprob': -17.905,
#                'prob': 1.67477821e-08},
#               {'AA': [{'AuId': 2144630512,
#                        'AuN': 'rion snow',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2089131864,
#                        'AuN': 'dan jurafsky',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'learning syntactic patterns for automatic hypernym '
#                      'discovery',
#                'Y': 2004,
#                'logprob': -17.439,
#                'prob': 2.66893828e-08},
#               {'AA': [{'AuId': 85537834,
#                        'AuN': 'sham m kakade',
#                        'DAfN': 'University of Pennsylvania'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'online bounds for bayesian algorithms',
#                'Y': 2004,
#                'logprob': -19.526,
#                'prob': 3.3110516e-09},
#               {'AA': [{'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'feature selection l 1 vs l 2 regularization and '
#                      'rotational invariance',
#                'Y': 2004,
#                'logprob': -17.36,
#                'prob': 2.88833654e-08},
#               {'AA': [{'AuId': 2075956027,
#                        'AuN': 'sebastian thrun',
#                        'DAfN': ''},
#                       {'AuId': 2131855225, 'AuN': 'yufeng liu', 'DAfN': ''},
#                       {'AuId': 2167404190, 'AuN': 'daphne koller', 'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''},
#                       {'AuId': 617670330,
#                        'AuN': 'zoubin ghahramani',
#                        'DAfN': ''},
#                       {'AuId': 2167801844,
#                        'AuN': 'hugh durrantwhyte',
#                        'DAfN': ''}],
#                'Ti': 'simultaneous localization and mapping with sparse '
#                      'extended information filters',
#                'Y': 2004,
#                'logprob': -17.284,
#                'prob': 3.11640703e-08},
#               {'AA': [{'AuId': 243981275,
#                        'AuN': 'pieter abbeel',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'apprenticeship learning via inverse reinforcement '
#                      'learning',
#                'Y': 2004,
#                'logprob': -16.5,
#                'prob': 6.82560338e-08},
#               {'AA': [{'AuId': 1997665198,
#                        'AuN': 'kristina toutanova',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2149153931,
#                        'AuN': 'christopher d manning',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'learning random walk models for inducing word dependency '
#                      'distributions',
#                'Y': 2004,
#                'logprob': -19.246,
#                'prob': 4.3809511e-09},
#               {'AA': [{'AuId': 243981275,
#                        'AuN': 'pieter abbeel',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'learning first order markov models for control',
#                'Y': 2004,
#                'logprob': -19.802,
#                'prob': 2.5124688e-09},
#               {'AA': [{'AuId': 243981275,
#                        'AuN': 'pieter abbeel',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2167404190,
#                        'AuN': 'daphne koller',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'learning factor graphs in polynomial time sample '
#                      'complexity',
#                'Y': 2005,
#                'logprob': -19.851,
#                'prob': 2.3923253e-09},
#               {'AA': [{'AuId': 2973633726,
#                        'AuN': 'masayoshi matsuoka',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2660686806,
#                        'AuN': 'alan chen',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2439822721,
#                        'AuN': 'surya p n singh',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2141511558,
#                        'AuN': 'adam coates',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2075956027,
#                        'AuN': 'sebastian thrun',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'autonomous helicopter tracking and localization using a '
#                      'self surveying camera array',
#                'Y': 2005,
#                'logprob': -19.536,
#                'prob': 3.2781061e-09},
#               {'AA': [{'AuId': 2129066351, 'AuN': 'rajat raina', 'DAfN': ''},
#                       {'AuId': 2111029421, 'AuN': 'aria haghighi', 'DAfN': ''},
#                       {'AuId': 2985349445,
#                        'AuN': 'christopher cox',
#                        'DAfN': ''},
#                       {'AuId': 2111429548,
#                        'AuN': 'jenny rose finkel',
#                        'DAfN': ''},
#                       {'AuId': 2103585224, 'AuN': 'jeff michels', 'DAfN': ''},
#                       {'AuId': 1997665198,
#                        'AuN': 'kristina toutanova',
#                        'DAfN': ''},
#                       {'AuId': 152590408, 'AuN': 'bill maccartney', 'DAfN': ''},
#                       {'AuId': 710824487,
#                        'AuN': 'mariecatherine de marneffe',
#                        'DAfN': ''},
#                       {'AuId': 2149153931,
#                        'AuN': 'christopher d manning',
#                        'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''}],
#                'Ti': 'robust textual inference using diverse knowledge sources',
#                'Y': 2005,
#                'logprob': -19.499,
#                'prob': 3.4016678e-09},
#               {'AA': [{'AuId': 243981275, 'AuN': 'pieter abbeel', 'DAfN': ''},
#                       {'AuId': 2141511558, 'AuN': 'adam coates', 'DAfN': ''},
#                       {'AuId': 1851008863,
#                        'AuN': 'michael montemerlo',
#                        'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''},
#                       {'AuId': 2075956027,
#                        'AuN': 'sebastian thrun',
#                        'DAfN': ''}],
#                'Ti': 'discriminative training of kalman filters',
#                'Y': 2005,
#                'logprob': -19.432,
#                'prob': 3.637388e-09},
#               {'AA': [{'AuId': 2141863260,
#                        'AuN': 'chuong b do',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'transfer learning for text classification',
#                'Y': 2005,
#                'logprob': -19.422,
#                'prob': 3.6739443e-09},
#               {'AA': [{'AuId': 2074347517,
#                        'AuN': 'drew bagnell',
#                        'DAfN': 'Carnegie Mellon University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'on local rewards and scaling distributed reinforcement '
#                      'learning',
#                'Y': 2005,
#                'logprob': -20.418,
#                'prob': 1.3569857e-09},
#               {'AA': [{'AuId': 2309890877,
#                        'AuN': 'erick delage',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2117954069,
#                        'AuN': 'honglak lee',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'automatic single image 3d reconstructions of indoor '
#                      'manhattan world scenes',
#                'Y': 2005,
#                'logprob': -19.084,
#                'prob': 5.1513862e-09},
#               {'AA': [{'AuId': 2129066351,
#                        'AuN': 'rajat raina',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2149153931,
#                        'AuN': 'christopher d manning',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'robust textual inference via learning and abductive '
#                      'reasoning',
#                'Y': 2005,
#                'logprob': -19.005,
#                'prob': 5.5748524e-09},
#               {'AA': [{'AuId': 243981275, 'AuN': 'pieter abbeel', 'DAfN': ''},
#                       {'AuId': 2141511558, 'AuN': 'adam coates', 'DAfN': ''},
#                       {'AuId': 1851008863,
#                        'AuN': 'michael montemerlo',
#                        'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''},
#                       {'AuId': 2075956027,
#                        'AuN': 'sebastian thrun',
#                        'DAfN': ''}],
#                'Ti': 'time complexity of sensor based vehicle routing',
#                'Y': 2005,
#                'logprob': -21.386,
#                'prob': 5.154401e-10},
#               {'AA': [{'AuId': 2099244378,
#                        'AuN': 'yirong shen',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2106732052,
#                        'AuN': 'matthias seeger',
#                        'DAfN': 'Max Planck Society'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'fast gaussian process regression using kd trees',
#                'Y': 2005,
#                'logprob': -18.992,
#                'prob': 5.6477986e-09},
#               {'AA': [{'AuId': 243981275,
#                        'AuN': 'pieter abbeel',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2000956124,
#                        'AuN': 'varun ganapathi',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'learning vehicular dynamics with application to modeling '
#                      'helicopters',
#                'Y': 2005,
#                'logprob': -19.1,
#                'prob': 5.0696199e-09},
#               {'AA': [{'AuId': 2111029421,
#                        'AuN': 'aria haghighi',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2149153931,
#                        'AuN': 'christopher d manning',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'robust textual inference via graph matching',
#                'Y': 2005,
#                'logprob': -18.87,
#                'prob': 6.3806236e-09},
#               {'AA': [{'AuId': 243981275,
#                        'AuN': 'pieter abbeel',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'exploration and apprenticeship learning in reinforcement '
#                      'learning',
#                'Y': 2005,
#                'logprob': -18.396,
#                'prob': 1.02498783e-08},
#               {'AA': [{'AuId': 2103585224,
#                        'AuN': 'jeff michels',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2139397739,
#                        'AuN': 'ashutosh saxena',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'high speed obstacle avoidance using monocular vision and '
#                      'reinforcement learning',
#                'Y': 2005,
#                'logprob': -17.74,
#                'prob': 1.9752219e-08},
#               {'AA': [{'AuId': 2036321405,
#                        'AuN': 'dragomir anguelov',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2569412340,
#                        'AuN': 'b taskarf',
#                        'DAfN': 'University of California, Berkeley'},
#                       {'AuId': 2699701377,
#                        'AuN': 'v chatalbashev',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2167404190,
#                        'AuN': 'daphne koller',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2150526599,
#                        'AuN': 'divya gupta',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2000496673,
#                        'AuN': 'geremy heitz',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'discriminative learning of markov random fields for '
#                      'segmentation of 3d scan data',
#                'Y': 2005,
#                'logprob': -17.821,
#                'prob': 1.82153717e-08},
#               {'AA': [{'AuId': 2139397739,
#                        'AuN': 'ashutosh saxena',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2288705612,
#                        'AuN': 'sung h chung',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'learning depth from single monocular images',
#                'Y': 2005,
#                'logprob': -17.358,
#                'prob': 2.89411899e-08},
#               {'AA': [{'AuId': 2117954069,
#                        'AuN': 'honglak lee',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'spam deobfuscation using a hidden markov model',
#                'Y': 2005,
#                'logprob': -19.494,
#                'prob': 3.4187187e-09},
#               {'AA': [{'AuId': 1891675207,
#                        'AuN': 'einat minkov',
#                        'DAfN': 'Carnegie Mellon University'},
#                       {'AuId': 2115385359,
#                        'AuN': 'william w cohen',
#                        'DAfN': 'Carnegie Mellon University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'a graphical framework for contextual search and name '
#                      'disambiguation in email',
#                'Y': 2006,
#                'logprob': -20.694,
#                'prob': 1.0296983e-09},
#               {'AA': [{'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'reinforcement learning and apprenticeship learning for '
#                      'robotic control',
#                'Y': 2006,
#                'logprob': -19.501,
#                'prob': 3.3948713e-09},
#               {'AA': [{'AuId': 2149153931,
#                        'AuN': 'christopher d manning',
#                        'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''}],
#                'Ti': 'exploring the utility of researchcyc for reasoning from '
#                      'natural language',
#                'Y': 2006,
#                'logprob': -21.349,
#                'prob': 5.348686e-10},
#               {'AA': [{'AuId': 2111429548,
#                        'AuN': 'jenny rose finkel',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2149153931,
#                        'AuN': 'christopher d manning',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'solving the problem of cascading errors approximate '
#                      'bayesian inference for linguistic annotation pipelines',
#                'Y': 2006,
#                'logprob': -19.176,
#                'prob': 4.6986058e-09},
#               {'AA': [{'AuId': 2395896173,
#                        'AuN': 'filip krsmanovic',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2609209247,
#                        'AuN': 'curtis spencer',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2089131864,
#                        'AuN': 'dan jurafsky',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'have we met mdp based speaker id for robot dialogue',
#                'Y': 2006,
#                'logprob': -19.336,
#                'prob': 4.0038878e-09},
#               {'AA': [{'AuId': 2010939805,
#                        'AuN': 'anna petrovskaya',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2135302480,
#                        'AuN': 'oussama khatib',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2075956027,
#                        'AuN': 'sebastian thrun',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'bayesian estimation for autonomous object manipulation '
#                      'based on tactile sensors',
#                'Y': 2006,
#                'logprob': -18.737,
#                'prob': 7.2882673e-09},
#               {'AA': [{'AuId': 2231049498,
#                        'AuN': 'michael j brzozowski',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2223574696,
#                        'AuN': 'kendra carattini',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 261822931,
#                        'AuN': 'scott r klemmer',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2223155010,
#                        'AuN': 'patrick mihelich',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2303015963,
#                        'AuN': 'jiang hu',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'grouptime preference based group scheduling',
#                'Y': 2006,
#                'logprob': -20.054,
#                'prob': 1.9528031e-09},
#               {'AA': [{'AuId': 2139397739,
#                        'AuN': 'ashutosh saxena',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 1969547113,
#                        'AuN': 'justin driemeyer',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2648823366,
#                        'AuN': 'justin kearns',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'robotic grasping of novel objects',
#                'Y': 2006,
#                'logprob': -18.396,
#                'prob': 1.02498783e-08},
#               {'AA': [{'AuId': 2117954069,
#                        'AuN': 'honglak lee',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2099244378,
#                        'AuN': 'yirong shen',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2115643295,
#                        'AuN': 'chihhan yu',
#                        'DAfN': 'Harvard University'},
#                       {'AuId': 3034950894,
#                        'AuN': 'g singh',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'quadruped robot obstacle negotiation via reinforcement '
#                      'learning',
#                'Y': 2006,
#                'logprob': -19.565,
#                'prob': 3.1844062e-09},
#               {'AA': [{'AuId': 243981275,
#                        'AuN': 'pieter abbeel',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2167404190,
#                        'AuN': 'daphne koller',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'learning factor graphs in polynomial time and sample '
#                      'complexity',
#                'Y': 2006,
#                'logprob': -18.387,
#                'prob': 1.03425436e-08},
#               {'AA': [{'AuId': 243981275,
#                        'AuN': 'pieter abbeel',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2110423698,
#                        'AuN': 'morgan quigley',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'using inaccurate models in reinforcement learning',
#                'Y': 2006,
#                'logprob': -18.749,
#                'prob': 7.2013308e-09},
#               {'AA': [{'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'reinforcement learning and apprenticeship learning for '
#                      'robotic control',
#                'Y': 2006,
#                'logprob': -19.501,
#                'prob': 3.3948713e-09},
#               {'AA': [{'AuId': 2325714424,
#                        'AuN': 'sunin lee',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2117954069,
#                        'AuN': 'honglak lee',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 243981275,
#                        'AuN': 'pieter abbeel',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'efficientl 1 regularized logistic regression',
#                'Y': 2006,
#                'logprob': -18.365,
#                'prob': 1.05726009e-08},
#               {'AA': [{'AuId': 1891675207,
#                        'AuN': 'einat minkov',
#                        'DAfN': 'Carnegie Mellon University'},
#                       {'AuId': 2115385359,
#                        'AuN': 'william w cohen',
#                        'DAfN': 'Carnegie Mellon University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'contextual search and name disambiguation in email using '
#                      'graphs',
#                'Y': 2006,
#                'logprob': -18.398,
#                'prob': 1.02293991e-08},
#               {'AA': [{'AuId': 665008183,
#                        'AuN': 'ted kremenek',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2009552882,
#                        'AuN': 'paul twohey',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2145185828,
#                        'AuN': 'godmar back',
#                        'DAfN': 'Virginia Tech'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2163716051,
#                        'AuN': 'dawson engler',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'from uncertainty to belief inferring the specification '
#                      'within',
#                'Y': 2006,
#                'logprob': -18.982,
#                'prob': 5.7045599e-09},
#               {'AA': [{'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'reinforcement learning and apprenticeship learning for '
#                      'robotic control',
#                'Y': 2006,
#                'logprob': -19.501,
#                'prob': 3.3948713e-09},
#               {'AA': [{'AuId': 2309890877,
#                        'AuN': 'erick delage',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2117954069,
#                        'AuN': 'honglak lee',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'a dynamic bayesian network model for autonomous 3d '
#                      'reconstruction from a single indoor image',
#                'Y': 2006,
#                'logprob': -18.333,
#                'prob': 1.09163955e-08},
#               {'AA': [{'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2141511558,
#                        'AuN': 'adam coates',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 1906408966,
# ...
#                       {'AuId': 3019689614, 'AuN': 'hao sheng', 'DAfN': ''},
#                       {'AuId': 2524433498, 'AuN': 'xiao chen', 'DAfN': ''},
#                       {'AuId': 2767758462, 'AuN': 'jingyi su', 'DAfN': ''},
#                       {'AuId': 2069881136, 'AuN': 'ram rajagopal', 'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''},
#                       {'AuId': 2980332076,
#                        'AuN': 'van thong huynh',
#                        'DAfN': ''},
#                       {'AuId': 2152015745, 'AuN': 'soohyung kim', 'DAfN': ''},
#                       {'AuId': 2133781946, 'AuN': 'in seop na', 'DAfN': ''},
#                       {'AuId': 2707298649, 'AuN': 'ujjwal baid', 'DAfN': ''},
#                       {'AuId': 3019999254, 'AuN': 'shubham innani', 'DAfN': ''},
#                       {'AuId': 2996189705, 'AuN': 'prasad dutande', 'DAfN': ''},
#                       {'AuId': 2323595367, 'AuN': 'bhakti baheti', 'DAfN': ''},
#                       {'AuId': 2533902488,
#                        'AuN': 'sanjay n talbar',
#                        'DAfN': ''},
#                       {'AuId': 3018289017, 'AuN': 'jianyu tang', 'DAfN': ''}],
#                'Ti': 'the 1st agriculture vision challenge methods and results',
#                'Y': 2020,
#                'logprob': -19.903,
#                'prob': 2.2711035e-09},
#               {'AA': [{'AuId': 2222836187,
#                        'AuN': 'pranav rajpurkar',
#                        'DAfN': ''},
#                       {'AuId': 3008726788, 'AuN': 'anirudh joshi', 'DAfN': ''},
#                       {'AuId': 3008637556, 'AuN': 'anuj pareek', 'DAfN': ''},
#                       {'AuId': 3008074961, 'AuN': 'phil chen', 'DAfN': ''},
#                       {'AuId': 2990503174,
#                        'AuN': 'amirhossein kiani',
#                        'DAfN': ''},
#                       {'AuId': 2770287955, 'AuN': 'jeremy irvin', 'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''},
#                       {'AuId': 1971466602,
#                        'AuN': 'matthew p lungren',
#                        'DAfN': ''}],
#                'Ti': 'chexpedition investigating generalization challenges for '
#                      'translation of chest x ray algorithms to the clinical '
#                      'setting',
#                'Y': 2020,
#                'logprob': -19.594,
#                'prob': 3.0933846e-09},
#               {'AA': [{'AuId': 2990503174,
#                        'AuN': 'amirhossein kiani',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2991371693,
#                        'AuN': 'bora uyumazturk',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2222836187,
#                        'AuN': 'pranav rajpurkar',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 3007607227,
#                        'AuN': 'alex wang',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2618869071,
#                        'AuN': 'rebecca w gao',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2903231689,
#                        'AuN': 'erik jones',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2963448786,
#                        'AuN': 'yifan yu',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 199442883,
#                        'AuN': 'curtis p langlotz',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2670387521,
#                        'AuN': 'robyn l ball',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 230016683,
#                        'AuN': 'thomas j montine',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2426787492,
#                        'AuN': 'brock a martin',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 1894042370,
#                        'AuN': 'gerald j berry',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2108567085,
#                        'AuN': 'michael g ozawa',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2014647186,
#                        'AuN': 'florette k hazard',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2177382966,
#                        'AuN': 'ryanne a brown',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2791123603,
#                        'AuN': 'simon b chen',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2891050040,
#                        'AuN': 'mona wood',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2902416097,
#                        'AuN': 'libby s allard',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2991543650,
#                        'AuN': 'lourdes ylagan',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2969364784,
#                        'AuN': 'jeanne shen',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'impact of a deep learning assistant on the '
#                      'histopathologic classification of liver cancer',
#                'Y': 2020,
#                'logprob': -19.285,
#                'prob': 4.2133828e-09},
#               {'AA': [{'AuId': 2942344533,
#                        'AuN': 'daniel rabinowitz',
#                        'DAfN': 'Maimonides Medical Center'},
#                       {'AuId': 2940515040,
#                        'AuN': 'andrew m wood',
#                        'DAfN': 'Maimonides Medical Center'},
#                       {'AuId': 2795667288,
#                        'AuN': 'allison marziliano',
#                        'DAfN': 'Northwell Health, New Hyde Park, NY.'},
#                       {'AuId': 2795671065,
#                        'AuN': 'andre perezorozco',
#                        'DAfN': 'Northwell Health, New Hyde Park, NY.'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Northwell Health, New Hyde Park, NY.'},
#                       {'AuId': 1231584458,
#                        'AuN': 'michael a diefenbach',
#                        'DAfN': 'Northwell Health, New Hyde Park, NY.'},
#                       {'AuId': 3010908219,
#                        'AuN': 'patrick samson',
#                        'DAfN': 'Northwell Health, New Hyde Park, NY.'},
#                       {'AuId': 286954628,
#                        'AuN': 'manish vira',
#                        'DAfN': 'Northwell Health, New Hyde Park, NY.'},
#                       {'AuId': 2131799381,
#                        'AuN': 'justin han',
#                        'DAfN': 'Northwell Health, New Hyde Park, NY.'},
#                       {'AuId': 2584092716,
#                        'AuN': 'ariel schulman',
#                        'DAfN': 'Maimonides Medical Center'},
#                       {'AuId': 2590697789,
#                        'AuN': 'simon j hall',
#                        'DAfN': 'Northwell Health, New Hyde Park, NY.'}],
#                'Ti': 'use of a risk stratification tool to guide evaluation of '
#                      'patients with asymptomatic microscopic hematuria',
#                'Y': 2020,
#                'logprob': -19.882,
#                'prob': 2.319301e-09},
#               {'AA': [{'AuId': 2222836187,
#                        'AuN': 'pranav rajpurkar',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2903423198,
#                        'AuN': 'allison park',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2770287955,
#                        'AuN': 'jeremy irvin',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 3021123605,
#                        'AuN': 'christopher chute',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2903273723,
#                        'AuN': 'michael bereket',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2460542254,
#                        'AuN': 'domenico mastrodicasa',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 199442883,
#                        'AuN': 'curtis p langlotz',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 1971466602,
#                        'AuN': 'matthew p lungren',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2158956040,
#                        'AuN': 'bhavik n patel',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'appendixnet deep learning for diagnosis of appendicitis '
#                      'from a small dataset of ct exams using video pretraining',
#                'Y': 2020,
#                'logprob': -19.249,
#                'prob': 4.3678279e-09},
#               {'AA': [{'AuId': 3017475023,
#                        'AuN': 'shihcheng huang',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 3017555587,
#                        'AuN': 'tanay kothari',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2122079672,
#                        'AuN': 'imon banerjee',
#                        'DAfN': 'Department of Biomedical Data Science, '
#                                'Stanford University, Stanford, USA'},
#                       {'AuId': 3021123605,
#                        'AuN': 'christopher chute',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2670387521,
#                        'AuN': 'robyn l ball',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 3019342575,
#                        'AuN': 'norah borus',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2122913919,
#                        'AuN': 'andrew c huang',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2158956040,
#                        'AuN': 'bhavik n patel',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2222836187,
#                        'AuN': 'pranav rajpurkar',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2770287955,
#                        'AuN': 'jeremy irvin',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 1983711249,
#                        'AuN': 'jared dunnmon',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2275274366,
#                        'AuN': 'joseph bledsoe',
#                        'DAfN': 'Intermountain Medical Center'},
#                       {'AuId': 2612237118,
#                        'AuN': 'katie shpanskaya',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 3019079215,
#                        'AuN': 'abhay dhaliwal',
#                        'DAfN': 'Michigan State University'},
#                       {'AuId': 2151085254,
#                        'AuN': 'roham t zamanian',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 1971466602,
#                        'AuN': 'matthew p lungren',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'penet a scalable deep learning model for automated '
#                      'diagnosis of pulmonary embolism using volumetric ct '
#                      'imaging',
#                'Y': 2020,
#                'logprob': -19.08,
#                'prob': 5.172033e-09},
#               {'AA': [{'AuId': 3019689614,
#                        'AuN': 'hao sheng',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2524433498,
#                        'AuN': 'xiao chen',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 3021100857,
#                        'AuN': 'jingyi su',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2069881136,
#                        'AuN': 'ram rajagopal',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''}],
#                'Ti': 'effective data fusion with generalized vegetation index '
#                      'evidence from land cover segmentation in agriculture',
#                'Y': 2020,
#                'logprob': -19.284,
#                'prob': 4.2175983e-09},
#               {'AA': [{'AuId': 2770287955,
#                        'AuN': 'jeremy irvin',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 3015856392,
#                        'AuN': 'andrew kondrich',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2963627392,
#                        'AuN': 'michael ko',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2222836187,
#                        'AuN': 'pranav rajpurkar',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2964033713,
#                        'AuN': 'behzad haghgoo',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 677403932,
#                        'AuN': 'bruce e landon',
#                        'DAfN': 'Harvard University'},
#                       {'AuId': 2807517896,
#                        'AuN': 'robert l phillips',
#                        'DAfN': 'American Board of Family Medicine'},
#                       {'AuId': 2033291363,
#                        'AuN': 'stephen petterson',
#                        'DAfN': 'American Academy of Family Physicians'},
#                       {'AuId': 2104401652,
#                        'AuN': 'andrew y ng',
#                        'DAfN': 'Stanford University'},
#                       {'AuId': 2273669580,
#                        'AuN': 'sanjay basu',
#                        'DAfN': 'Imperial College London'},
#                       {'AuId': 2273669580,
#                        'AuN': 'sanjay basu',
#                        'DAfN': 'Harvard University'}],
#                'Ti': 'incorporating machine learning and social determinants '
#                      'of health indicators into prospective risk adjustment '
#                      'for health plan payments',
#                'Y': 2020,
#                'logprob': -19.012,
#                'prob': 5.5359647e-09},
#               {'AA': [{'AuId': 2538666078, 'AuN': 'sharon zhou', 'DAfN': ''},
#                       {'AuId': 3034145645, 'AuN': 'eric zelikman', 'DAfN': ''},
#                       {'AuId': 3015832789, 'AuN': 'fred lu', 'DAfN': ''},
#                       {'AuId': 2104401652, 'AuN': 'andrew y ng', 'DAfN': ''},
#                       {'AuId': 248646318,
#                        'AuN': 'stefano ermon',
#                        'DAfN': 'Stanford University'}],
#                'Ti': 'evaluating the disentanglement of deep generative models '
#                      'through manifold topology',
#                'Y': 2020,
#                'logprob': -19.304,
#                'prob': 4.1340842e-09}],
#  'expr': 'And(Composite(AA.AuId=2104401652),Y=[1980,2021])',
#  'timed_out': False}

# %%
df = pd.read_csv("data_file.csv")
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  ...                 Affiliation        Country
# 0             0             2  ...  Carnegie Mellon University  United States
# 1             1             2  ...  Carnegie Mellon University      Australia
# 2             2             4  ...                         NaN            NaN
# 3             3             7  ...  Carnegie Mellon University  United States
# 4             4             7  ...  Carnegie Mellon University      Australia
# ..          ...           ...  ...                         ...            ...
# 271         271          1414  ...         Stanford University  United States
# 272         272          1431  ...         Stanford University  United States
# 273         273          1437  ...                         NaN            NaN
# 274         274          1446  ...         Stanford University  United States
# 275         275          1452  ...                         NaN            NaN
#
# [276 rows x 8 columns]

# %%
grid = pd.read_csv('/content/drive/My Drive/AI Index Visualization Project/DATASETS/Conference data/Country data/Grid/grid.csv')
grid = grid[['Name','Country']].rename(columns={'Name':'Affiliation'})
grid
# Out:
#                                              Affiliation    Country
# 0                         Australian National University  Australia
# 1                                      Monash University  Australia
# 2                               University of Queensland  Australia
# 3                                   Macquarie University  Australia
# 4                                            UNSW Sydney  Australia
# ...                                                  ...        ...
# 97790                           Advanced Analysis Center      Japan
# 97791                           Genetic Resources Center      Japan
# 97792  Research Center for Agricultural Information T...      Japan
# 97793                     Center for Seeds and Seedlings      Japan
# 97794               Agri-Food Business Innovation Center      Japan
#
# [97795 rows x 2 columns]

# %%
grid[grid['Country']=='United States'].head(40)
# Out:
#                                             Affiliation        Country
# 43                               Ludwig Cancer Research  United States
# 53                            Naval Postgraduate School  United States
# 56                              Smithsonian Institution  United States
# 62                                                 Arup  United States
# 73                Washington State Department of Health  United States
# 79                                       Luther College  United States
# 81                           Boston Children's Hospital  United States
# 84                      United States Geological Survey  United States
# 89                               Hypres (United States)  United States
# 91      National Oceanic and Atmospheric Administration  United States
# 93                                            Boys Town  United States
# 108                  Washington University in St. Louis  United States
# 110                             Oregon State University  United States
# 114   World Health Organization Regional Office for ...  United States
# 215                  Oregon Health & Science University  United States
# 236                                  Cornell University  United States
# 619                        Morehouse School of Medicine  United States
# 751         University of North Carolina at Chapel Hill  United States
# 965                     University of Wisconsin–Madison  United States
# 992           Association of Science-Technology Centers  United States
# 1021                              University of Florida  United States
# 1074                            University of Rochester  United States
# 1089                               Princeton University  United States
# 1090                            Northwestern University  United States
# 1104                          Michigan State University  United States
# 1127                            University of Minnesota  United States
# 1136                  California Pacific Medical Center  United States
# 1161              University of California, Los Angeles  United States
# 1196                         University of Rhode Island  United States
# 1200                            Public Health Institute  United States
# 1207                                    Ohio University  United States
# 1216                 California Institute of Technology  United States
# 1225                                University of Maine  United States
# 1226                           Johns Hopkins University  United States
# 1241                                Columbia University  United States
# 1246                           University of Pittsburgh  United States
# 1247                                    Rice University  United States
# 1264                            George Mason University  United States
# 1310                     University of Nebraska–Lincoln  United States
# 1321                        New Mexico State University  United States
