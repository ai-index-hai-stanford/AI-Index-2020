# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#@title ##### Imports
# !pip install squarify
import pandas as pd
import plotly.offline as pyo
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
import plotly.graph_objects as go
import squarify
import plotly.express as px

# %%
#@title ##### Load data path
data_path = "/content/drive/My Drive/AI Index Visualization Project/DATASETS/OECD/Artificial intelligence" #@param {type:"string"}

# %%
#@title Top countries in AI research by policy area by year
Publication_Type = "Conference" #@param ["Conference","Journals","Patents","Repository","Research Publication"]
Policy_Area = "Competition" #@param ["Agriculture","Competition","Corporate governance","Development","Digital","Economy","Education","Employment","Environment","Finance insurance","Health","Industry entrepreneurship","Innovation","Investment","Public governance","Science technology","Social welfare issues","Tax","Trade","Transport"]
df = pd.read_csv(f"{data_path}/Policy/{Publication_Type}/{Policy_Area}.csv")

Year = "2020" #@param [1980,1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
Year = int(Year)
Number_of_countries = 15 #@param {type:"slider", min:1, max:25, step:1}

da = df[df['Year']==Year]
da = da.sort_values('Value',ascending=False).head(Number_of_countries).sort_values('Value')
fig = go.Figure(data=[go.Bar(y=list(da['Country']), x=da['Value'],orientation='h')])

fig.add_layout_image(
    dict(
        source="https://pbs.twimg.com/profile_images/928845333349543937/xzRkcN08.jpg",
        xref="paper", yref="paper",
        x=-0.05, y=-0.26,
        sizex=0.23, sizey=0.23,
        xanchor="left", yanchor="bottom"
    )
)

fig.update_layout(
    title = {
        'text': 'Top countries in AI research by policy area in {}'.format(Year),
        'y':0.9,
        'x':0,
        'xanchor': 'left',
        'yanchor': 'top'},
        titlefont= {
            "size": 30,
            
        },
    yaxis_title = "Country",
    xaxis_title = "AI Research"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b0122405-e05c-4535-a420-37c529815bc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b0122405-e05c-4535-a420-37c529815bc2")) {
#                     Plotly.newPlot(
#                         'b0122405-e05c-4535-a420-37c529815bc2',
# ...

# %%
#@title Top countries in AI research by policy area by year(Pie chart)
Publication_Type = "Conference" #@param ["Conference","Journals","Patents","Repository","Research Publication"]
Policy_Area = "Competition" #@param ["Agriculture","Competition","Corporate governance","Development","Digital","Economy","Education","Employment","Environment","Finance insurance","Health","Industry entrepreneurship","Innovation","Investment","Public governance","Science technology","Social welfare issues","Tax","Trade","Transport"]
df = pd.read_csv(f"{data_path}/Policy/{Publication_Type}/{Policy_Area}.csv")

Year = "2020" #@param [1980,1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
Year = int(Year)
Number_of_countries = 15 #@param {type:"slider", min:1, max:25, step:1}

da = df[df['Year']==Year]
da = da.sort_values('Value',ascending=False).head(Number_of_countries).sort_values('Value')
fig = px.pie(da, values='Value', names='Country', title=f'Top countries in AI research in {Year}')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="237cc72f-d099-4613-aa9c-6ce6f0b57b43" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("237cc72f-d099-4613-aa9c-6ce6f0b57b43")) {
#                     Plotly.newPlot(
#                         '237cc72f-d099-4613-aa9c-6ce6f0b57b43',
# ...

# %%
#@title Country AI research by policy area
Publication_Type = "Research Publication" #@param ["Conference","Journals","Patents","Repository","Research Publication"]
Policy_Area = "Agriculture" #@param ["Agriculture","Competition","Corporate governance","Development","Digital","Economy","Education","Employment","Environment","Finance insurance","Health","Industry entrepreneurship","Innovation","Investment","Public governance","Science technology","Social welfare issues","Tax","Trade","Transport"]
df = pd.read_csv(f"{data_path}/Policy/{Publication_Type}/{Policy_Area}.csv")

fig = go.Figure()
Country = "India"#@param ['Australia', 'Brazil', 'Canada', 'Switzerland', 'Chile', 'China (People’s Republic of)', 'EU27', 'United Kingdom', 'Ghana', 'India', 'International Organizations', 'Israel', 'Japan', 'Mexico', 'Mauritius', 'Nigeria', 'Norway', 'New Zealand', 'Pakistan', 'Philippines', 'Sierra Leone', 'United States', 'Egypt', 'Indonesia', 'Iraq', 'South Africa', 'Kenya', 'Sri Lanka', 'Myanmar', 'Saudi Arabia', 'Sudan', 'Singapore', 'Uruguay', 'Costa Rica', 'Iran', 'Papua New Guinea', 'Qatar', 'Russia', 'Turkey', 'Chinese Taipei', 'Tanzania', 'United Arab Emirates', 'Ethiopia', 'Kuwait', 'Argentina', 'Bangladesh', 'Honduras', 'Cambodia', 'Trinidad and Tobago', 'Venezuela', 'Colombia', 'Jordan', 'Malaysia', 'Palestinian Authority', 'Panama', 'Puerto Rico', 'Zimbabwe', 'Burundi', 'Korea', 'Malawi', 'Thailand', 'Bahrain', 'Senegal', 'Uganda', 'Serbia', 'Botswana', 'Morocco', 'Niger', 'Eswatini (Swaziland)', 'Ecuador', 'Hong Kong (China)', 'Nepal', 'Bolivia', 'Georgia', 'Lebanon', 'Oman', 'Rwanda', 'Syrian Arab Republic', 'Ukraine', 'Cameroon', 'Mozambique', 'Namibia', 'Bosnia and Herzegovina', 'Mongolia', 'Albania', 'Lesotho', 'Viet Nam', 'Yemen', 'Zambia', 'Peru', 'El Salvador', 'Belarus', 'Uzbekistan', 'Burkina Faso', 'Côte d’Ivoire', 'Cuba', 'Eritrea', 'Lao People’s Democratic Republic', 'Tunisia', 'Dominican Republic', 'Algeria', 'Jamaica', 'Moldova', 'Mauritania', 'Paraguay', 'Tajikistan', 'Azerbaijan', 'Guatemala', 'Nicaragua', 'Mali', 'Armenia', 'Democratic Republic of the Congo', 'Kazakhstan', 'Libya', 'Togo', 'Madagascar', 'South Sudan', 'Chad', 'Congo', 'Guinea-Bissau', 'Kyrgyzstan', 'Gabon', 'Gambia']
da = df[df['Country']==Country]
fig = go.Figure(data=[go.Bar(y=da['Value'], x=da['Year'])])

fig.add_layout_image(
    dict(
        source="https://pbs.twimg.com/profile_images/928845333349543937/xzRkcN08.jpg",
        xref="paper", yref="paper",
        x=-0.05, y=-0.26,
        sizex=0.23, sizey=0.23,
        xanchor="left", yanchor="bottom"
    )
)

fig.update_layout(
    title = {
        'text': 'AI research by policy area in {} over time'.format(Country),
        'y':0.9,
        'x':0,
        'xanchor': 'left',
        'yanchor': 'top'},
        titlefont= {
            "size": 30,
            
        },
    yaxis_title = "AI Research",
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="13265a8a-71be-4542-9c55-b3b6a018374f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("13265a8a-71be-4542-9c55-b3b6a018374f")) {
#                     Plotly.newPlot(
#                         '13265a8a-71be-4542-9c55-b3b6a018374f',
# ...

# %%
#@title Growth rate of AI vs CS vs ALL
Publication_Type = "Conference" #@param ["Conference","Journals","Patents","Repository","Publication"]
df_gr = pd.read_csv(f"{data_path}/Growth rate/{Publication_Type}-AI-vs-CS-vs-All-comparison.csv")
fig = go.Figure()
colors = ['Blue','Red','Green']
df_ai = df_gr[df_gr['Topic']=="Publications from artificial intelligence only"]
df_cs = df_gr[df_gr['Topic']=="Publications from computer science only"]
df_rp = df_gr[df_gr['Topic']=="Research Publications"]


fig.add_trace(go.Scatter(x=df_ai['Year'], y=df_ai['Value'], name='Publications from artificial intelligence', 
                         line_color=colors[0], hovertext=df_ai['Value'], opacity=0.7))
fig.add_trace(go.Scatter(x=df_cs['Year'], y=df_cs['Value'], name='Publications from computer science', 
                         line_color=colors[1], hovertext=df_cs['Value'], opacity=0.7))
fig.add_trace(go.Scatter(x=df_rp['Year'], y=df_rp['Value'], name='Research Publications', 
                         line_color=colors[2], hovertext=df_rp['Value'], opacity=0.7))


fig.add_layout_image(
    dict(
        source="https://pbs.twimg.com/profile_images/928845333349543937/xzRkcN08.jpg",
        xref="paper", yref="paper",
        x=-0.08, y=-0.28,
        sizex=0.23, sizey=0.23,
        xanchor="left", yanchor="bottom"
    )
)

fig.update_layout(
    title = {
        'text': 'Growth rate of AI vs CS vs ALL',
        'y':0.9,
        'x':0,
        'xanchor': 'left',
        'yanchor': 'top'},
        titlefont= {
            "size": 30,
            
        },
    yaxis_title = "Number of Publications",
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8bf07826-2f96-44a9-b0dc-45638d22b2bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8bf07826-2f96-44a9-b0dc-45638d22b2bd")) {
#                     Plotly.newPlot(
#                         '8bf07826-2f96-44a9-b0dc-45638d22b2bd',
# ...

# %%
#@title Sub-Topics in AI comparison
Publication_Type = "Conference" #@param ["Conference","Journals","Patents","Repository","Publication"]
df_st = pd.read_csv(f"{data_path}/Sub-topics/AI-{Publication_Type}-subtopics-comparison.csv")
fig = go.Figure()
colors = ['Blue','Red','Green',"Yellow","Black","Brown"]
df_ai = df_st[df_st['Topic']=="Machine learning"]
df_cv = df_st[df_st['Topic']=="Computer vision"]
df_fl = df_st[df_st['Topic']=="Fuzzy logic"]
df_ann = df_st[df_st['Topic']=="Artificial neural network"]
df_nlp = df_st[df_st['Topic']=="NLP Semantics"]
df_sa = df_st[df_st['Topic']=="Search algorithms"]


fig.add_trace(go.Scatter(x=df_ai['Year'], y=df_ai['Value'], name='Machine learning', 
                         line_color=colors[0], hovertext=df_ai['Value'], opacity=0.7))
fig.add_trace(go.Scatter(x=df_cv['Year'], y=df_cv['Value'], name='Computer vision', 
                         line_color=colors[1], hovertext=df_cv['Value'], opacity=0.7))
fig.add_trace(go.Scatter(x=df_fl['Year'], y=df_fl['Value'], name='Fuzzy logic', 
                         line_color=colors[2], hovertext=df_fl['Value'], opacity=0.7))
fig.add_trace(go.Scatter(x=df_ann['Year'], y=df_ann['Value'], name='Artificial neural network', 
                         line_color=colors[3], hovertext=df_ann['Value'], opacity=0.7))
fig.add_trace(go.Scatter(x=df_nlp['Year'], y=df_nlp['Value'], name='NLP Semantics', 
                         line_color=colors[4], hovertext=df_nlp['Value'], opacity=0.7))
fig.add_trace(go.Scatter(x=df_sa['Year'], y=df_sa['Value'], name='Search algorithms', 
                         line_color=colors[5], hovertext=df_sa['Value'], opacity=0.7))


fig.add_layout_image(
    dict(
        source="https://pbs.twimg.com/profile_images/928845333349543937/xzRkcN08.jpg",
        xref="paper", yref="paper",
        x=-0.08, y=-0.28,
        sizex=0.23, sizey=0.23,
        xanchor="left", yanchor="bottom"
    )
)

fig.update_layout(
    title = {
        'text': 'Sub-Topics in AI comparison',
        'y':0.9,
        'x':0,
        'xanchor': 'left',
        'yanchor': 'top'},
        titlefont= {
            "size": 30,
            
        },
    yaxis_title = "Number of Publications",
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c347bbf9-3282-4053-8632-00c49beb9d7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c347bbf9-3282-4053-8632-00c49beb9d7d")) {
#                     Plotly.newPlot(
#                         'c347bbf9-3282-4053-8632-00c49beb9d7d',
# ...

# %%
#@title Top countries in AI research 
Publication_Type = "Publication" #@param ["Conference","Journals","Patents","Repository","Publication"]
df_country = pd.read_csv(f"{data_path}/Country/AI_{Publication_Type}.csv")

Year = "2020" #@param [1980,1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
Year = int(Year)
Number_of_countries = 15 #@param {type:"slider", min:1, max:25, step:1}
da = df_country[df_country['Year']==Year]
da = da.sort_values('Value',ascending=False).head(Number_of_countries).sort_values('Value')
fig = go.Figure(data=[go.Bar(y=list(da['Country']), x=da['Value'],orientation='h')])

fig.add_layout_image(
    dict(
        source="https://pbs.twimg.com/profile_images/928845333349543937/xzRkcN08.jpg",
        xref="paper", yref="paper",
        x=-0.05, y=-0.26,
        sizex=0.23, sizey=0.23,
        xanchor="left", yanchor="bottom"
    )
)

fig.update_layout(
    title = {
        'text': 'Top countries in AI research in {}'.format(Year),
        'y':0.9,
        'x':0,
        'xanchor': 'left',
        'yanchor': 'top'},
        titlefont= {
            "size": 30,
            
        },
    yaxis_title = "Country",
    xaxis_title = "AI Research"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f5318d7b-3e78-46ad-890d-4fb3711bd460" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f5318d7b-3e78-46ad-890d-4fb3711bd460")) {
#                     Plotly.newPlot(
#                         'f5318d7b-3e78-46ad-890d-4fb3711bd460',
# ...

# %%
#@title Top countries in AI research 
Publication_Type = "Publication" #@param ["Conference","Journals","Patents","Repository","Publication"]
df_country = pd.read_csv(f"{data_path}/Country/AI_{Publication_Type}.csv")

Year = "2020" #@param [1980,1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
Year = int(Year)
da = df_country[df_country['Year']==Year]
Number_of_countries = 11 #@param {type:"slider", min:1, max:25, step:1}

da = da.sort_values('Value',ascending=False).head(Number_of_countries).sort_values('Value')

fig = px.pie(da, values='Value', names='Country', title=f'Top countries in AI research in {Year}')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="92c19f3c-1b5c-4a2a-8183-6e01e4c54806" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("92c19f3c-1b5c-4a2a-8183-6e01e4c54806")) {
#                     Plotly.newPlot(
#                         '92c19f3c-1b5c-4a2a-8183-6e01e4c54806',
# ...

# %%
#@title AI research Country Collaboration
Publication_Type = "Publication" #@param ["Conference","Journals","Patents","Repository","Publication"]
df_col = pd.read_csv(f"{data_path}/Collaboration/AI-{Publication_Type}-collaborations-countries.csv")

fig = go.Figure()

Year = "2019" #@param [1980,1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

Country = "EU27"#@param ['Australia', 'Brazil', 'Canada', 'Switzerland', 'Chile', 'China (People’s Republic of)', 'EU27', 'United Kingdom', 'Ghana', 'India', 'International Organizations', 'Israel', 'Japan', 'Mexico', 'Mauritius', 'Nigeria', 'Norway', 'New Zealand', 'Pakistan', 'Philippines', 'Sierra Leone', 'United States', 'Egypt', 'Indonesia', 'Iraq', 'South Africa', 'Kenya', 'Sri Lanka', 'Myanmar', 'Saudi Arabia', 'Sudan', 'Singapore', 'Uruguay', 'Costa Rica', 'Iran', 'Papua New Guinea', 'Qatar', 'Russia', 'Turkey', 'Chinese Taipei', 'Tanzania', 'United Arab Emirates', 'Ethiopia', 'Kuwait', 'Argentina', 'Bangladesh', 'Honduras', 'Cambodia', 'Trinidad and Tobago', 'Venezuela', 'Colombia', 'Jordan', 'Malaysia', 'Palestinian Authority', 'Panama', 'Puerto Rico', 'Zimbabwe', 'Burundi', 'Korea', 'Malawi', 'Thailand', 'Bahrain', 'Senegal', 'Uganda', 'Serbia', 'Botswana', 'Morocco', 'Niger', 'Eswatini (Swaziland)', 'Ecuador', 'Hong Kong (China)', 'Nepal', 'Bolivia', 'Georgia', 'Lebanon', 'Oman', 'Rwanda', 'Syrian Arab Republic', 'Ukraine', 'Cameroon', 'Mozambique', 'Namibia', 'Bosnia and Herzegovina', 'Mongolia', 'Albania', 'Lesotho', 'Viet Nam', 'Yemen', 'Zambia', 'Peru', 'El Salvador', 'Belarus', 'Uzbekistan', 'Burkina Faso', 'Côte d’Ivoire', 'Cuba', 'Eritrea', 'Lao People’s Democratic Republic', 'Tunisia', 'Dominican Republic', 'Algeria', 'Jamaica', 'Moldova', 'Mauritania', 'Paraguay', 'Tajikistan', 'Azerbaijan', 'Guatemala', 'Nicaragua', 'Mali', 'Armenia', 'Democratic Republic of the Congo', 'Kazakhstan', 'Libya', 'Togo', 'Madagascar', 'South Sudan', 'Chad', 'Congo', 'Guinea-Bissau', 'Kyrgyzstan', 'Gabon', 'Gambia']
Number_of_countries = 15 #@param {type:"slider", min:1, max:25, step:1}

da = df_col[df_col['First Country']==Country]
da = da[da['Year'] == Year]
da = da[da['Second Country']!=Country]
da = da.sort_values('Value',ascending=False).head(Number_of_countries).sort_values('Value')
fig = go.Figure(data=[go.Bar(y=list(da['Second Country']), x=da['Value'],orientation='h')])

fig.add_layout_image(
    dict(
        source="https://pbs.twimg.com/profile_images/928845333349543937/xzRkcN08.jpg",
        xref="paper", yref="paper",
        x=-0.05, y=-0.26,
        sizex=0.23, sizey=0.23,
        xanchor="left", yanchor="bottom"
    )
)

fig.update_layout(
    title = {
        'text': 'Top countries in AI research Collaborating with {}'.format(Country),
        'y':0.9,
        'x':0,
        'xanchor': 'left',
        'yanchor': 'top'},
        titlefont= {
            "size": 30,
            
        },
    yaxis_title = "Country",
    xaxis_title = "AI Research"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1aa3eb4e-b604-44b8-9a51-7e3ec897f606" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1aa3eb4e-b604-44b8-9a51-7e3ec897f606")) {
#                     Plotly.newPlot(
#                         '1aa3eb4e-b604-44b8-9a51-7e3ec897f606',
# ...

# %%
#@title AI research Country Collaboration (Sankey plots)
Publication_Type = "Publication" #@param ["Conference","Journals","Patents","Repository","Publication"]
df_col = pd.read_csv(f"{data_path}/Collaboration/AI-{Publication_Type}-collaborations-countries.csv")

fig = go.Figure()

Year = "2019" #@param [1980,1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

Country = "EU27"#@param ['Australia', 'Brazil', 'Canada', 'Switzerland', 'Chile', 'China (People’s Republic of)', 'EU27', 'United Kingdom', 'Ghana', 'India', 'International Organizations', 'Israel', 'Japan', 'Mexico', 'Mauritius', 'Nigeria', 'Norway', 'New Zealand', 'Pakistan', 'Philippines', 'Sierra Leone', 'United States', 'Egypt', 'Indonesia', 'Iraq', 'South Africa', 'Kenya', 'Sri Lanka', 'Myanmar', 'Saudi Arabia', 'Sudan', 'Singapore', 'Uruguay', 'Costa Rica', 'Iran', 'Papua New Guinea', 'Qatar', 'Russia', 'Turkey', 'Chinese Taipei', 'Tanzania', 'United Arab Emirates', 'Ethiopia', 'Kuwait', 'Argentina', 'Bangladesh', 'Honduras', 'Cambodia', 'Trinidad and Tobago', 'Venezuela', 'Colombia', 'Jordan', 'Malaysia', 'Palestinian Authority', 'Panama', 'Puerto Rico', 'Zimbabwe', 'Burundi', 'Korea', 'Malawi', 'Thailand', 'Bahrain', 'Senegal', 'Uganda', 'Serbia', 'Botswana', 'Morocco', 'Niger', 'Eswatini (Swaziland)', 'Ecuador', 'Hong Kong (China)', 'Nepal', 'Bolivia', 'Georgia', 'Lebanon', 'Oman', 'Rwanda', 'Syrian Arab Republic', 'Ukraine', 'Cameroon', 'Mozambique', 'Namibia', 'Bosnia and Herzegovina', 'Mongolia', 'Albania', 'Lesotho', 'Viet Nam', 'Yemen', 'Zambia', 'Peru', 'El Salvador', 'Belarus', 'Uzbekistan', 'Burkina Faso', 'Côte d’Ivoire', 'Cuba', 'Eritrea', 'Lao People’s Democratic Republic', 'Tunisia', 'Dominican Republic', 'Algeria', 'Jamaica', 'Moldova', 'Mauritania', 'Paraguay', 'Tajikistan', 'Azerbaijan', 'Guatemala', 'Nicaragua', 'Mali', 'Armenia', 'Democratic Republic of the Congo', 'Kazakhstan', 'Libya', 'Togo', 'Madagascar', 'South Sudan', 'Chad', 'Congo', 'Guinea-Bissau', 'Kyrgyzstan', 'Gabon', 'Gambia']
Number_of_countries = 10 #@param {type:"slider", min:1, max:25, step:1}
da = df_col[df_col['First Country']==Country]
da = da[da['Year'] == Year]
da = da[da['Second Country']!=Country]
da = da.sort_values('Value',ascending=False).head(Number_of_countries).sort_values('Value').drop('Year',axis=1)
target = []
for i in range(1,len(list(da['Second Country'])) + 1):
  target.append(i)

fig = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 15,
      thickness = 20,
      line = dict(color = "black", width = 0.5),
      label = [Country]+list(da['Second Country']),
      color = "Blue"
    ),
    link = dict(
      source = [0]*len(list(da['First Country'])), # indices correspond to labels, eg A1, A2, A2, B1, ...
      target = target,
      value = list(da['Value']),
      label = list(da['Second Country'])
  ))])

fig.update_layout(title_text="AI research Country Collaboration", font_size=20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="583fd1fc-9c9b-480a-adf4-995b1fa751af" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("583fd1fc-9c9b-480a-adf4-995b1fa751af")) {
#                     Plotly.newPlot(
#                         '583fd1fc-9c9b-480a-adf4-995b1fa751af',
# ...

# %% [markdown]
# #### Institute list: <a href="https://docs.google.com/spreadsheets/d/1-KMpBLfB-Q5BQzvQmP3VQfr3YAfYWQly7XtNf1-P-r8/edit?usp=sharing">here</a>

# %%
#@title AI research Institution Collaboration
Publication_Type = "Journals" #@param ["Conference","Journals","Patents","Repository","Publication"]
df_ins_col = pd.read_csv(f"{data_path}/Institute/Collaboration/AI-{Publication_Type}-collaborations-institutions.csv")

fig = go.Figure()

Year = "2017" #@param [1980,1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

Institute = "Massachusetts Institute of Technology" #@param {type:"string"}
Number_of_institutions = 15 #@param {type:"slider", min:1, max:25, step:1}

da = df_ins_col[df_ins_col['First Institution']==Institute]
da = da[da['Year'] == Year]
da = da[da['Second Institution']!=Institute]
da = da.sort_values('Value',ascending=False).head(Number_of_institutions).sort_values('Value')
fig = go.Figure(data=[go.Bar(y=list(da['Second Institution']), x=da['Value'],orientation='h')])

fig.add_layout_image(
    dict(
        source="https://pbs.twimg.com/profile_images/928845333349543937/xzRkcN08.jpg",
        xref="paper", yref="paper",
        x=-0.05, y=-0.26,
        sizex=0.23, sizey=0.23,
        xanchor="left", yanchor="bottom"
    )
)

fig.update_layout(
    title = {
        'text': 'Top Institutions in AI research Collaborating with {}'.format(Institute),
        'y':0.9,
        'x':0,
        'xanchor': 'left',
        'yanchor': 'top'},
        titlefont= {
            "size": 30,
            
        },
    yaxis_title = "Institutes",
    xaxis_title = "AI Research"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e09c310f-db4d-4cef-8c75-744e8b18d1da" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e09c310f-db4d-4cef-8c75-744e8b18d1da")) {
#                     Plotly.newPlot(
#                         'e09c310f-db4d-4cef-8c75-744e8b18d1da',
# ...

# %%
#@title AI research Institution Collaboration
Publication_Type = "Journals" #@param ["Conference","Journals","Patents","Repository","Publication"]
df_ins_col = pd.read_csv(f"{data_path}/Institute/Collaboration/AI-{Publication_Type}-collaborations-institutions.csv")

fig = go.Figure()

Year = "2017" #@param [1980,1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
Number_of_institutions = 13 #@param {type:"slider", min:1, max:25, step:1}

Institute = "Massachusetts Institute of Technology" #@param {type:"string"}
da = df_ins_col[df_ins_col['First Institution']==Institute]
da = da[da['Year'] == Year]
da = da[da['Second Institution']!=Institute]
da = da.sort_values('Value',ascending=False).head(Number_of_institutions).sort_values('Value').drop('Year',axis=1)
target = []
for i in range(1,len(list(da['Second Institution'])) + 1):
  target.append(i)

fig = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 15,
      thickness = 20,
      line = dict(color = "black", width = 0.5),
      label = [Institute]+list(da['Second Institution']),
      color = "Blue"
    ),
    link = dict(
      source = [0]*len(list(da['First Institution'])), # indices correspond to labels, eg A1, A2, A2, B1, ...
      target = target,
      value = list(da['Value']),
      label = list(da['Second Institution'])
  ))])

fig.update_layout(title_text="AI research Institution Collaboration", font_size=20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1ffac528-403c-424b-934a-4fabcde8531c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1ffac528-403c-424b-934a-4fabcde8531c")) {
#                     Plotly.newPlot(
#                         '1ffac528-403c-424b-934a-4fabcde8531c',
# ...
